# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("/content/survey lung cancer.csv")
data.head()
# Out:
#   GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0      M   69        1               2        2              1
# 1      M   74        2               1        1              1
# 2      F   59        1               1        1              2
# 3      M   63        2               2        2              1
# 4      F   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN LUNG_CANCER
# 0                    2                      2           2         YES
# 1                    2                      2           2         YES
# 2                    2                      1           2          NO
# 3                    1                      2           2          NO
# 4                    2                      1           1          NO

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

encoder = LabelEncoder()
scaler = StandardScaler()

data["GENDER"] = encoder.fit_transform(data["GENDER"])
data["LUNG_CANCER"] = encoder.fit_transform(data["LUNG_CANCER"])

data.head()
# Out:
#    GENDER  AGE  SMOKING  YELLOW_FINGERS  ANXIETY  PEER_PRESSURE  \
# 0       1   69        1               2        2              1
# 1       1   74        2               1        1              1
# 2       0   59        1               1        1              2
# 3       1   63        2               2        2              1
# 4       0   63        1               2        1              1
#
#    CHRONIC DISEASE  FATIGUE   ALLERGY   WHEEZING  ALCOHOL CONSUMING  COUGHING  \
# 0                1         2         1         2                  2         2
# 1                2         2         2         1                  1         1
# 2                1         2         1         2                  1         2
# 3                1         1         1         1                  2         1
# 4                1         1         1         2                  1         2
#
#    SHORTNESS OF BREATH  SWALLOWING DIFFICULTY  CHEST PAIN  LUNG_CANCER
# 0                    2                      2           2            1
# 1                    2                      2           2            1
# 2                    2                      1           2            0
# 3                    1                      2           2            0
# 4                    2                      1           1            0

# %%
from sklearn.model_selection import train_test_split

X = data.drop(columns=['LUNG_CANCER'])
y = data['LUNG_CANCER']
X= scaler.fit_transform(X)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2,
                                                    stratify=data["LUNG_CANCER"], random_state=42)

# %%
y
# Out:
# 0      1
# 1      1
# 2      0
# 3      0
# 4      0
#       ..
# 304    1
# 305    1
# 306    1
# 307    1
# 308    1
# Name: LUNG_CANCER, Length: 309, dtype: int64

# %%
dup = data[data.duplicated()].shape[0]
print(f"There are {dup} duplicate entries among {data.shape[0]} entries in this dataset.")

data.drop_duplicates(keep='first',inplace=True)
print(f"\nAfter removing duplicate entries there are {data.shape[0]} entries in this dataset.")
# Out:
# There are 33 duplicate entries among 309 entries in this dataset.
#
# After removing duplicate entries there are 276 entries in this dataset.

# %%
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras import regularizers
from tensorflow.keras.optimizers import Adam

regularization_parameter = 0.003

neural_model = Sequential([tf.keras.layers.Dense(units=32, input_dim=(X_train.shape[-1]), activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=64, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=128, activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dropout(0.3),
                    tf.keras.layers.Dense(units=16,activation="relu", kernel_regularizer = regularizers.l1(regularization_parameter)),
                    tf.keras.layers.Dense(units=1, activation="sigmoid")
                    ])

print(neural_model.summary())
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_35 (Dense)                     │ (None, 32)                  │             512 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_11 (Dropout)                 │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_36 (Dense)                     │ (None, 64)                  │           2,112 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_37 (Dense)                     │ (None, 128)                 │           8,320 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_12 (Dropout)                 │ (None, 128)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_38 (Dense)                     │ (None, 16)                  │           2,064 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_39 (Dense)                     │ (None, 1)                   │              17 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 13,025 (50.88 KB)
#  Trainable params: 13,025 (50.88 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
from tensorflow.keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=30, restore_best_weights=True)

neural_model.compile(optimizer = Adam(learning_rate = 0.001),
                     loss = "binary_crossentropy",
                     metrics = ["accuracy"])

history = neural_model.fit(X_train, y_train,
                           epochs = 150,
                           verbose = 1,
                           batch_size = 64,
                           validation_data = (X_test, y_test),
                           callbacks=[early_stopping]
                                )
print(f"Best validation accuracy: {max(history.history['val_accuracy']) * 100:.2f}%")
# Out:
# Epoch 1/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - accuracy: 0.9520 - loss: 0.2260 - val_accuracy: 0.9194 - val_loss: 0.2696
# Epoch 2/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9599 - loss: 0.2228 - val_accuracy: 0.9355 - val_loss: 0.2685
# Epoch 3/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9362 - loss: 0.2404 - val_accuracy: 0.9355 - val_loss: 0.2659
# Epoch 4/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9625 - loss: 0.2053 - val_accuracy: 0.9355 - val_loss: 0.2697
# Epoch 5/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9472 - loss: 0.2288 - val_accuracy: 0.9355 - val_loss: 0.2706
# Epoch 6/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9557 - loss: 0.2353 - val_accuracy: 0.9355 - val_loss: 0.2670
# Epoch 7/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9572 - loss: 0.2262 - val_accuracy: 0.9355 - val_loss: 0.2687
# Epoch 8/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9730 - loss: 0.2085 - val_accuracy: 0.9355 - val_loss: 0.2724
# Epoch 9/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9509 - loss: 0.2211 - val_accuracy: 0.9355 - val_loss: 0.2736
# Epoch 10/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9708 - loss: 0.2196 - val_accuracy: 0.9355 - val_loss: 0.2722
# Epoch 11/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9645 - loss: 0.2159 - val_accuracy: 0.9355 - val_loss: 0.2689
# Epoch 12/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9610 - loss: 0.2266 - val_accuracy: 0.9355 - val_loss: 0.2700
# Epoch 13/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9597 - loss: 0.2152 - val_accuracy: 0.9355 - val_loss: 0.2729
# Epoch 14/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9662 - loss: 0.2031 - val_accuracy: 0.9355 - val_loss: 0.2731
# Epoch 15/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9728 - loss: 0.2048 - val_accuracy: 0.9355 - val_loss: 0.2707
# Epoch 16/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9489 - loss: 0.2227 - val_accuracy: 0.9355 - val_loss: 0.2706
# Epoch 17/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9425 - loss: 0.2389 - val_accuracy: 0.9194 - val_loss: 0.2733
# Epoch 18/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9699 - loss: 0.2045 - val_accuracy: 0.9194 - val_loss: 0.2751
# Epoch 19/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9636 - loss: 0.2251 - val_accuracy: 0.9194 - val_loss: 0.2753
# Epoch 20/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9673 - loss: 0.2009 - val_accuracy: 0.9194 - val_loss: 0.2760
# Epoch 21/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9556 - loss: 0.2264 - val_accuracy: 0.9355 - val_loss: 0.2753
# Epoch 22/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9630 - loss: 0.2098 - val_accuracy: 0.9355 - val_loss: 0.2766
# Epoch 23/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9641 - loss: 0.2034 - val_accuracy: 0.9355 - val_loss: 0.2796
# Epoch 24/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9799 - loss: 0.1969 - val_accuracy: 0.9355 - val_loss: 0.2773
# Epoch 25/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - accuracy: 0.9629 - loss: 0.2046 - val_accuracy: 0.9194 - val_loss: 0.2769
# Epoch 26/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 0.9667 - loss: 0.2144 - val_accuracy: 0.9355 - val_loss: 0.2786
# Epoch 27/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9657 - loss: 0.2199 - val_accuracy: 0.9194 - val_loss: 0.2795
# Epoch 28/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9652 - loss: 0.2153 - val_accuracy: 0.9194 - val_loss: 0.2785
# Epoch 29/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9500 - loss: 0.2239 - val_accuracy: 0.9355 - val_loss: 0.2747
# Epoch 30/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9782 - loss: 0.1942 - val_accuracy: 0.9355 - val_loss: 0.2754
# Epoch 31/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9566 - loss: 0.2205 - val_accuracy: 0.9355 - val_loss: 0.2771
# Epoch 32/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9736 - loss: 0.2062 - val_accuracy: 0.9355 - val_loss: 0.2786
# Epoch 33/150
# 4/4 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 0.9614 - loss: 0.1986 - val_accuracy: 0.9355 - val_loss: 0.2774
# Best validation accuracy: 93.55%

# %%
y_pred=neural_model.predict(X_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step

# %%
from sklearn.metrics import classification_report, confusion_matrix
pred= (y_pred > 0.5).astype(int)

report = classification_report(y_test,pred)
print("Test Accuracy: " + report + '\n' + classification_report(y_test, pred))
# Out:
# Test Accuracy:               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.96      0.96      0.96        54
#
#     accuracy                           0.94        62
#    macro avg       0.86      0.86      0.86        62
# weighted avg       0.94      0.94      0.94        62
#
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         8
#            1       0.96      0.96      0.96        54
#
#     accuracy                           0.94        62
#    macro avg       0.86      0.86      0.86        62
# weighted avg       0.94      0.94      0.94        62

# %%
neural_model.save('/content/drive/My Drive//lung_neural.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
