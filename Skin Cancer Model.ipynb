# %%
# !pip install Augmentor

import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
import random
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.image as img
import warnings
import Augmentor
import kagglehub

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from keras.layers import Input, Dense, Dropout, Flatten, Conv2D, MaxPool2D ,Rescaling
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import SparseCategoricalCrossentropy
from tensorflow.keras.callbacks import EarlyStopping
from glob import glob
from PIL import Image

warnings.filterwarnings('ignore')
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

path = kagglehub.dataset_download("nodoubttome/skin-cancer9-classesisic")

path_to_training_dataset = '../input/skin-cancer9-classesisic/Skin cancer ISIC The International Skin Imaging Collaboration/Train/'
path_to_testing_dataset = '../input/skin-cancer9-classesisic/Skin cancer ISIC The International Skin Imaging Collaboration/Test/'
# Out:
# Requirement already satisfied: Augmentor in /usr/local/lib/python3.10/dist-packages (0.2.12)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (10.4.0)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (4.66.5)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from Augmentor) (1.26.4)

# %%
class_names=['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma',
             'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis',
             'squamous cell carcinoma', 'vascular lesion']

for class_ in class_names:
    training_aug = Augmentor.Pipeline(path_to_training_dataset + class_, output_directory='/kaggle/working/data/train/' + class_)
    training_aug.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    training_aug.sample(1000)

for class_ in class_names:
    testing_aug = Augmentor.Pipeline(path_to_testing_dataset + class_, output_directory='/kaggle/working/data/test/' + class_)
    testing_aug.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    testing_aug.sample(100)
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /kaggle/working/data/train/actinic keratosis.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DDC7A3F10>: 100%|██████████| 1000/1000 [00:11<00:00, 84.19 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /kaggle/working/data/train/basal cell carcinoma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DDC7BFAF0>: 100%|██████████| 1000/1000 [00:11<00:00, 86.63 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /kaggle/working/data/train/dermatofibroma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DDC76F010>: 100%|██████████| 1000/1000 [00:12<00:00, 81.19 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /kaggle/working/data/train/melanoma.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D0DE4D1CB80>: 100%|██████████| 1000/1000 [01:14<00:00, 13.37 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /kaggle/working/data/train/nevus.
# Processing <PIL.Image.Image image mode=RGB size=767x576 at 0x7D0DDC62F130>: 100%|██████████| 1000/1000 [01:07<00:00, 14.85 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /kaggle/working/data/train/pigmented benign keratosis.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D0DDC65B700>: 100%|██████████| 1000/1000 [00:12<00:00, 82.31 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /kaggle/working/data/train/seborrheic keratosis.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D0DE4D1E050>: 100%|██████████| 1000/1000 [00:29<00:00, 33.49 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /kaggle/working/data/train/squamous cell carcinoma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DE4A1F010>: 100%|██████████| 1000/1000 [00:12<00:00, 79.55 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /kaggle/working/data/train/vascular lesion.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DE4A24340>: 100%|██████████| 1000/1000 [00:12<00:00, 79.89 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/actinic keratosis.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D0DDC7046D0>: 100%|██████████| 100/100 [00:01<00:00, 69.62 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/basal cell carcinoma.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D0DDC706B90>: 100%|██████████| 100/100 [00:01<00:00, 82.68 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/dermatofibroma.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D0DDC707880>: 100%|██████████| 100/100 [00:36<00:00,  2.77 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/melanoma.
# Processing <PIL.Image.Image image mode=RGB size=1022x767 at 0x7D0E570587F0>: 100%|██████████| 100/100 [00:05<00:00, 17.17 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/nevus.
# Processing <PIL.Image.Image image mode=RGB size=1022x767 at 0x7D0DE4A26F50>: 100%|██████████| 100/100 [00:03<00:00, 29.08 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/pigmented benign keratosis.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7D0DDC704790>: 100%|██████████| 100/100 [00:01<00:00, 79.49 Samples/s]
# Initialised with 3 image(s) found.
# Output directory set to /kaggle/working/data/test/seborrheic keratosis.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7D0DE4D1D750>: 100%|██████████| 100/100 [00:03<00:00, 32.71 Samples/s]
# Initialised with 16 image(s) found.
# Output directory set to /kaggle/working/data/test/squamous cell carcinoma.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DDC705540>: 100%|██████████| 100/100 [00:34<00:00,  2.92 Samples/s]
# Initialised with 3 image(s) found.
# Output directory set to /kaggle/working/data/test/vascular lesion.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7D0DDC707C40>: 100%|██████████| 100/100 [00:01<00:00, 76.70 Samples/s]

# %%
training_dir = pathlib.Path('/kaggle/working/data/train')
testing_dir = pathlib.Path('/kaggle/working/data/test')
random_seed = 42
random.seed(random_seed)

train_ds = tf.keras.preprocessing.image_dataset_from_directory(training_dir, seed=random_seed, validation_split=0.2, 
                                                               subset='training', image_size=(224, 224), batch_size=32)
val_ds = tf.keras.preprocessing.image_dataset_from_directory(training_dir, seed=random_seed, validation_split=0.2,
                                                             subset='validation', image_size=(224, 224), batch_size=32)
test_ds = tf.keras.preprocessing.image_dataset_from_directory(testing_dir, seed=random_seed, image_size=(224, 224), batch_size=32)
# Out:
# Found 9000 files belonging to 9 classes.
# Using 7200 files for training.
# Found 9000 files belonging to 9 classes.
# Using 1800 files for validation.
# Found 900 files belonging to 9 classes.

# %%
model = Sequential([
    Input(shape=(224, 224, 3)), 
    Rescaling(1.0/255), 
    
    Conv2D(32, 3,padding="same",activation='relu'), 
    MaxPool2D(pool_size=(2, 2)), 

    Conv2D(64, 3,padding="same",activation='relu'), 
    MaxPool2D(pool_size=(2, 2)), 

    Conv2D(128, 3,padding="same",activation='relu'), 
    MaxPool2D(pool_size=(2, 2)), 
    Dropout(0.2), 

    Conv2D(256, 3,padding="same",activation='relu'), 
    MaxPool2D(pool_size=(2, 2)), 
    Dropout(0.25), 

    Conv2D(512, 3,padding="same",activation='relu'), 
    MaxPool2D(pool_size=(2, 2)), 
    Dropout(0.3), 

    Flatten(), 
    Dense(1024, activation="relu"), 
    Dense(9, activation='softmax'), ])

adam = tf.keras.optimizers.Adam(learning_rate=0.001)
model.compile(optimizer=adam, loss=SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ rescaling_2 (Rescaling)              │ (None, 224, 224, 3)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_10 (Conv2D)                   │ (None, 224, 224, 32)        │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_10 (MaxPooling2D)      │ (None, 112, 112, 32)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_11 (Conv2D)                   │ (None, 112, 112, 64)        │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_11 (MaxPooling2D)      │ (None, 56, 56, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_12 (Conv2D)                   │ (None, 56, 56, 128)         │          73,856 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_12 (MaxPooling2D)      │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_6 (Dropout)                  │ (None, 28, 28, 128)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_13 (Conv2D)                   │ (None, 28, 28, 256)         │         295,168 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_13 (MaxPooling2D)      │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_7 (Dropout)                  │ (None, 14, 14, 256)         │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_14 (Conv2D)                   │ (None, 14, 14, 512)         │       1,180,160 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_14 (MaxPooling2D)      │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_8 (Dropout)                  │ (None, 7, 7, 512)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten_2 (Flatten)                  │ (None, 25088)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1024)                │      25,691,136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 9)                   │           9,225 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 27,268,937 (104.02 MB)
#  Trainable params: 27,268,937 (104.02 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

history = model.fit(train_ds, validation_data=val_ds, 
                    epochs=40, callbacks=[early_stopping])

print(f"Best validation accuracy: {max(history.history['val_accuracy']) * 100:.2f}%")
# Out:
# Epoch 1/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 23s 81ms/step - accuracy: 0.1077 - loss: 2.2051 - val_accuracy: 0.1561 - val_loss: 2.1913
# Epoch 2/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 78ms/step - accuracy: 0.1580 - loss: 2.1531 - val_accuracy: 0.2850 - val_loss: 1.8883
# Epoch 3/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 79ms/step - accuracy: 0.2876 - loss: 1.8312 - val_accuracy: 0.4094 - val_loss: 1.5102
# Epoch 4/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.4245 - loss: 1.5002 - val_accuracy: 0.4639 - val_loss: 1.3477
# Epoch 5/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.5087 - loss: 1.2847 - val_accuracy: 0.5194 - val_loss: 1.2662
# Epoch 6/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.5673 - loss: 1.1542 - val_accuracy: 0.6239 - val_loss: 1.0267
# Epoch 7/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 79ms/step - accuracy: 0.6086 - loss: 1.0101 - val_accuracy: 0.6500 - val_loss: 0.9479
# Epoch 8/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.6954 - loss: 0.8284 - val_accuracy: 0.7094 - val_loss: 0.8212
# Epoch 9/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.7381 - loss: 0.7000 - val_accuracy: 0.7706 - val_loss: 0.7081
# Epoch 10/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.7570 - loss: 0.6629 - val_accuracy: 0.7622 - val_loss: 0.6960
# Epoch 11/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.8228 - loss: 0.4776 - val_accuracy: 0.8333 - val_loss: 0.5114
# Epoch 12/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.8450 - loss: 0.4031 - val_accuracy: 0.8311 - val_loss: 0.5050
# Epoch 13/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 78ms/step - accuracy: 0.8692 - loss: 0.3540 - val_accuracy: 0.8489 - val_loss: 0.4704
# Epoch 14/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 78ms/step - accuracy: 0.8870 - loss: 0.3187 - val_accuracy: 0.8622 - val_loss: 0.4280
# Epoch 15/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.8897 - loss: 0.3273 - val_accuracy: 0.8611 - val_loss: 0.4352
# Epoch 16/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.9061 - loss: 0.2612 - val_accuracy: 0.8667 - val_loss: 0.3895
# Epoch 17/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9111 - loss: 0.2347 - val_accuracy: 0.8594 - val_loss: 0.4046
# Epoch 18/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9134 - loss: 0.2313 - val_accuracy: 0.8261 - val_loss: 0.5449
# Epoch 19/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9013 - loss: 0.2775 - val_accuracy: 0.8633 - val_loss: 0.4274
# Epoch 20/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 78ms/step - accuracy: 0.9272 - loss: 0.1986 - val_accuracy: 0.8850 - val_loss: 0.3570
# Epoch 21/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 20s 75ms/step - accuracy: 0.9322 - loss: 0.1869 - val_accuracy: 0.8861 - val_loss: 0.3748
# Epoch 22/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 76ms/step - accuracy: 0.9250 - loss: 0.1960 - val_accuracy: 0.8856 - val_loss: 0.3466
# Epoch 23/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9346 - loss: 0.1690 - val_accuracy: 0.8461 - val_loss: 0.5400
# Epoch 24/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9325 - loss: 0.1901 - val_accuracy: 0.8806 - val_loss: 0.4055
# Epoch 25/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9325 - loss: 0.1765 - val_accuracy: 0.8928 - val_loss: 0.3651
# Epoch 26/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9395 - loss: 0.1593 - val_accuracy: 0.8767 - val_loss: 0.4560
# Epoch 27/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9306 - loss: 0.1875 - val_accuracy: 0.8883 - val_loss: 0.4160
# Epoch 28/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9276 - loss: 0.1913 - val_accuracy: 0.8811 - val_loss: 0.4187
# Epoch 29/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9396 - loss: 0.1654 - val_accuracy: 0.8944 - val_loss: 0.4290
# Epoch 30/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 18s 78ms/step - accuracy: 0.9430 - loss: 0.1543 - val_accuracy: 0.8822 - val_loss: 0.3798
# Epoch 31/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9448 - loss: 0.1468 - val_accuracy: 0.8878 - val_loss: 0.3843
# Epoch 32/40
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 17s 75ms/step - accuracy: 0.9456 - loss: 0.1467 - val_accuracy: 0.8717 - val_loss: 0.3856
# Best validation accuracy: 89.44%

# %%
y_pred_probs = model.predict(train_ds, verbose=1)
y_pred = np.concatenate([np.argmax(model.predict(batch), axis=-1) for batch, _ in train_ds])
y_true = np.concatenate([labels.numpy() for _, labels in train_ds])

from sklearn.metrics import classification_report
print(classification_report(y_true, y_pred))
# Out:
# 225/225 ━━━━━━━━━━━━━━━━━━━━ 8s 36ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
#               precision    recall  f1-score   support
#
#            0       0.12      0.13      0.13       795
#            1       0.11      0.11      0.11       815
#            2       0.10      0.10      0.10       801
#            3       0.12      0.10      0.11       793
#            4       0.13      0.13      0.13       799
#            5       0.12      0.12      0.12       795
#            6       0.11      0.12      0.11       813
#            7       0.14      0.14      0.14       785
#            8       0.09      0.09      0.09       804
#
#     accuracy                           0.12      7200
#    macro avg       0.12      0.12      0.12      7200
# weighted avg       0.12      0.12      0.12      7200

# %%
image = Image.open("/kaggle/working/data/test/actinic keratosis/actinic keratosis_original_ISIC_0010512.jpg_39e415b2-4082-4c72-ad91-b498749bd4dd.jpg")
if image.mode != 'RGB':
        image = image.convert('RGB')

image = image.resize((224, 224))
image_array = np.array(image)
# image_array = image_array / 255.0
image_array =  image_array.reshape(1, 224, 224, 3)
predictions = model.predict(image_array)
print(predictions.argmax())
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step
# 4

# %%
model.save("kaggle/working/skins_classifier.h5")
